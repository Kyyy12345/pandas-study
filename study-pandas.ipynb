# %%
# !pip install pandas
import pandas as pd
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
# 데이터 형식
# 시리즈 : 1차원 데이터 + index(label 이름표 붙인 것)
s= pd.Series([1, 2, 3, 4, 5])

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
#데이터프레임: 2차원 데이터를 다룬다

# %%
#파이썬의 딕셔너리 key: col_name, value: data
students = pd.DataFrame({
    'name':    ['김민준','이서현','박지우','최하은','정도윤'],
    'age':     [22, 23, 22, 24, 23],
    'math':    [85, 92, 78, 95, 88],
    'english': [76, 88, 91, 70, 85],
    'grade':   ['B', 'A', 'B', 'A', 'A']
})

# %%
students.head
# Out:
# <bound method NDFrame.head of   name  age  math  english grade
# 0  김민준   22    85       76     B
# 1  이서현   23    92       88     A
# 2  박지우   22    78       91     B
# 3  최하은   24    95       70     A
# 4  정도윤   23    88       85     A>

# %%
students.shape
# Out:
# (5, 5)

# %%
students.dtypes
# Out:
# name         str
# age        int64
# math       int64
# english    int64
# grade        str
# dtype: object

# %%
students.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      str
#  1   age      5 non-null      int64
#  2   math     5 non-null      int64
#  3   english  5 non-null      int64
#  4   grade    5 non-null      str
# dtypes: int64(3), str(2)
# memory usage: 332.0 bytes

# %%
students.describe()
# Out:
#             age       math    english
# count   5.00000   5.000000   5.000000
# mean   22.80000  87.600000  82.000000
# std     0.83666   6.580274   8.746428
# min    22.00000  78.000000  70.000000
# 25%    22.00000  85.000000  76.000000
# 50%    23.00000  88.000000  85.000000
# 75%    23.00000  92.000000  88.000000
# max    24.00000  95.000000  91.000000

# %%
students.head
# Out:
# <bound method NDFrame.head of   name  age  math  english grade
# 0  김민준   22    85       76     B
# 1  이서현   23    92       88     A
# 2  박지우   22    78       91     B
# 3  최하은   24    95       70     A
# 4  정도윤   23    88       85     A>

# %%
# 데이터 프레임 인덱싱 => Series
# DataFrame = Series를 Columns로 모아둔것
students['name']
# Out:
# 0    김민준
# 1    이서현
# 2    박지우
# 3    최하은
# 4    정도윤
# Name: name, dtype: str

# %%
# 2개 컬럼 이상을 선택했을 때, DataFrame으로 차원이 유지된다. (컬럼이 선택된 데이터프레임)
students[['name', 'math']], type(students[['name', 'math']])
# Out:
# pandas.DataFrame
